# %% [markdown]
# Imports:

# %%
from __future__ import print_function
from __future__ import division
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchsummary import summary
import numpy as np
import torchvision
from torchvision import datasets, models, transforms as T
import matplotlib.pyplot as plt
import time
import os
import copy
import pandas as pd
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset
import plotly_express as px
from sklearn.metrics import classification_report
print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  1.13.0+cu117
# Torchvision Version:  0.14.0+cu117

# %% [markdown]
# Hyperparameters:

# %%
img_height = 224
img_width = img_height
num_classes = 10

batch_size = 32
n_epochs = 20
train_base = True
optimizer_name = "Adam"
SGD_momentum = 0.9
learning_rate = 0.001
learn_rate_step = 5
learn_rate_gamma = 0.7
use_cuda = True
torch.cuda.amp.autocast(enabled=True)

# %% [markdown]
# Image Transform Functions (For Later):

# %%
class MyAddGaussNoise(object):
    def __init__(self, input_size, mean=0.0, std=None, add_noise_probability=1.0):
        assert isinstance(input_size, (int, tuple))
        assert isinstance(mean, (int, float))
        assert isinstance(std, (int, float)) or std is None
        assert isinstance(add_noise_probability, (float))


        if isinstance(input_size, int):
            self.input_size = (input_size, input_size)
        else:
            assert len(input_size) == 2
            self.input_size = input_size

        self.mean = mean

        if std is not None:
            assert std > 0.0
            self.std = std
        else:
            self.std = std

        assert add_noise_probability > 0.0 and add_noise_probability <= 1.0
        self.add_noise_prob = add_noise_probability


    def __call__(self, spectrogram):
        if np.random.random() > self.add_noise_prob:
            return spectrogram

        # set some std value 
        min_pixel_value = np.min(spectrogram)
        if self.std is None:
            std_factor = 0.03     # factor number 
        std = np.abs(min_pixel_value*std_factor)

        # generate a white noise spectrogram
        gauss_mask = np.random.normal(self.mean, 
                                    std, 
                                    size=self.input_size).astype('float32')
        
        # add white noise to the sound spectrogram
        noisy_visual = spectrogram + gauss_mask

        return noisy_visual

class MyRightShift(object):
    def __init__(self, input_size, width_shift_range, shift_probability=1.0):
        assert isinstance(input_size, (int, tuple))
        assert isinstance(width_shift_range, (int, float))
        assert isinstance(shift_probability, (float))

        if isinstance(input_size, int):
            self.input_size = (input_size, input_size)
        else:
            assert len(input_size) == 2
            self.input_size = input_size

        if isinstance(width_shift_range, int):
            assert width_shift_range > 0
            assert width_shift_range <= self.input_size[1]
            self.width_shift_range = width_shift_range
        else:
            assert width_shift_range > 0.0
            assert width_shift_range <= 1.0
            self.width_shift_range = int(width_shift_range * self.input_size[1])
                        
        assert shift_probability > 0.0 and shift_probability <= 1.0
        self.shift_prob = shift_probability

    def __call__(self, image):
        if np.random.random() > self.shift_prob:
            return image

        # create a new array filled with the min value
        shifted_image= np.full(self.input_size, np.min(image), dtype='float32')

        # randomly choose a start postion
        rand_position = np.random.randint(1, self.width_shift_range)

        # shift the image
        shifted_image[:,rand_position:] = copy.deepcopy(image[:,:-rand_position])

        return shifted_image

#applying required transformations on the dataset
img_transforms = {
    'train':
    T.Compose([
        MyAddGaussNoise(input_size = img_height,add_noise_probability=0.5),
        MyRightShift(input_size = img_height, width_shift_range=0.9, shift_probability=0.5),
        T.ToTensor(),
        T.Normalize([0.5],[0.5])
        ]),

    'valid':
    T.Compose([
        T.ToTensor(),
        T.Normalize([0.5], [0.5])
        ]),

    'test':
    T.Compose([
        T.ToTensor(),
        T.Normalize([0.5], [0.5])
        ]),
     }

# %% [markdown]
# Custom Dataset Object (UrbanSound8kDataset):

# %%
class UrbanSound8kDataset(Dataset):
    def __init__(self, featuresdf, transform=None):
        assert isinstance(featuresdf, pd.DataFrame)
        assert len(featuresdf.columns) == 3
        
        self.transform = transform

        self.featuresdf = featuresdf

    def __len__(self):
        return len(self.featuresdf)

    def __getitem__(self, index):
        if torch.is_tensor(index):
            index = index.tolist()

        cochleagram, label, fold = self.featuresdf.iloc[index]

        if self.transform is not None:
           cochleagram = self.transform(cochleagram)

        if not torch.is_tensor(cochleagram):
            cochleagram = torch.as_tensor(cochleagram.astype('float'))

        label = torch.as_tensor(np.array(label)).type(torch.LongTensor)

        cochleagram = cochleagram.expand(3,-1,-1).float()

        return cochleagram, label

# %% [markdown]
# Initialize Model Architecture Function:

# %%
def init_model():
    model_transfer = models.vgg16(weights='VGG16_Weights.DEFAULT')

    for param in model_transfer.parameters():
        param.requires_grad = train_base
    in_features = model_transfer.classifier[0].in_features

    #this should remain constant
    model_transfer.fc = nn.Sequential(  
        nn.Linear(in_features, num_classes),
        )

    # selecting loss function
    criterion_transfer = nn.CrossEntropyLoss()

    #using Adam classifier
    if optimizer_name == 'Adam':
        optimizer_transfer = optim.Adam(model_transfer.parameters(), lr=learning_rate)

    if optimizer_name == 'SGD':
        optimizer_transfer = optim.SGD(model_transfer.parameters(), lr=learning_rate, momentum=SGD_momentum)

    scheduler_transfer = torch.optim.lr_scheduler.StepLR(optimizer_transfer, step_size=learn_rate_step, gamma=learn_rate_gamma)

    if use_cuda:
        model_transfer = model_transfer.cuda()

    return model_transfer, optimizer_transfer, criterion_transfer, scheduler_transfer

# %% [markdown]
# Training Loop Function:

# %%
def train_model(n_epochs, loaders, model, optimizer, criterion, scheduler, fold_k, data_type, model_name, save_path):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    torch.autograd.set_detect_anomaly(True)
    valid_loss_min = np.Inf 
    epochs = []
    trainingloss = []
    validationloss = []
    valaccuracy = []
    learningrates = []

    for epoch in range(1, n_epochs+1):
        # initialize the variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        correct = 0.0
        total = 0.0

        preds = []
        targets = []
        
        ###################
        # training the model #
        ###################
        model.train()
        for batch_idx, (data, target) in enumerate(loaders['train']):     
            if use_cuda:
                data, target = data.cuda(), target.cuda()   
            
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
           
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
    
        ######################    
        # validating the model #
        ######################
        model.eval()
        for batch_idx, (data, target) in enumerate(loaders['valid']):
            if use_cuda:
                data, target = data.cuda(), target.cuda()

            output = model(data)
            loss = criterion(output, target)
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))
            pred = output.data.max(1,keepdim=True)[1]
            preds.append(pred)
            targets.append(target)
            # compare predictions
            correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
            total += data.size(0)
        
        train_loss = train_loss/len(train_ds)
        valid_loss = valid_loss/len(val_ds)
        valid_acc = correct / total
        current_lr = optimizer.param_groups[0]['lr']
        scheduler.step()

        trainingloss.append(train_loss)
        validationloss.append(valid_loss)
        valaccuracy.append(valid_acc)
        epochs.append(epoch)
        learningrates.append(current_lr)

        # printing training/validation statistics 
        print('Epoch: {} \nTraining Loss: {:.6f} \nValidation Loss: {:.6f} \nValidation Accuracy: {:.6f} \nCorrect: {} / {} \nCurrent LR: {}'.format(
            epoch, 
            train_loss,
            valid_loss,
            valid_acc,
            correct,
            total,
            current_lr
            ))
        
        ## saving the model if validation loss has decreased
        if valid_loss < valid_loss_min:
            torch.save(model.state_dict(), save_path)
            
            valid_loss_min = valid_loss

    #GATHER TRAINING RESULTS IN DATAFRAME
    validationloss = [i.cpu().tolist() for i in validationloss]
    trainingloss = [i.cpu().tolist() for i in trainingloss]
    zipped_data = list(zip(epochs, learningrates, trainingloss, validationloss, valaccuracy))
    train_report = pd.DataFrame(zipped_data,columns=['Epoch','Learning Rate','Training Loss','Validation Loss','Validation Accuracy'])
    train_report['Test Fold'] = fold_k
    train_report['Model'] = model_name
    train_report['Data Representation'] = data_type
    train_report = train_report[['Model','Data Representation', 'Test Fold', 'Epoch', 'Learning Rate', 'Training Loss', 'Validation Loss', 'Validation Accuracy']]
    
    # return trained model
    return model, train_report

# %% [markdown]
# Training Script (Load Data From Disk, Train on All 10 Folds, Evaluate on Test Data, Generate Training and Test Metric Reports):

# %%
# Representation Name
data_type = 'Cochleagram'

# Model Name
model_name = 'VGG16'

# Perform 10 fold validation
for fold_k in range(1,num_classes+1):
    featuresdf = pd.read_pickle('cgram_224_comp3.pkl')
    model_transfer, optimizer_transfer, criterion_transfer, scheduler_transfer = init_model()
    train_df = featuresdf[featuresdf['fold'] != fold_k]
    val_df = featuresdf[featuresdf['fold'] == fold_k]
    test_fold = fold_k

    train_ds = UrbanSound8kDataset(train_df, transform=img_transforms['train'])
    val_ds = UrbanSound8kDataset(val_df, transform=img_transforms['valid'])

    #Creating loaders for the dataset
    loaders_transfer={
        'train':torch.utils.data.DataLoader(train_ds,batch_size,shuffle=True),
        'valid':torch.utils.data.DataLoader(val_ds,batch_size,shuffle=False)
    }

    del featuresdf, train_df, val_df

    if fold_k == 1:
        #TRAIN THE MODEL AND SAVE RESULTS TO TRAIN_REPORT
        train_report = train_model(n_epochs, loaders_transfer, model_transfer, optimizer_transfer, criterion_transfer, scheduler_transfer, fold_k, data_type, model_name, model_name + '_' + data_type + '_fold' + str(fold_k) + '.pt')[1]
    else:
        #TRAIN THE MODEL AND ADD DATA TO TRAIN_REPORT
        train_report_temp = train_model(n_epochs, loaders_transfer, model_transfer, optimizer_transfer, criterion_transfer, scheduler_transfer, fold_k, data_type, model_name, model_name + '_' + data_type + '_fold' + str(fold_k) + '.pt')[1]
        train_report = pd.concat([train_report, train_report_temp])
    
    del model_transfer, optimizer_transfer, criterion_transfer, scheduler_transfer
    
    #RELOAD FINAL CHECKPOINTED MODEL IN FOR VALIDATION RESULTS
    model_transfer = init_model()[0]
    model_transfer.load_state_dict(torch.load(model_name + '_' + data_type + '_fold' + str(fold_k) + '.pt'))
    model_transfer.eval()

    #PERFORM FINAL INFERENCE ON VALIDATION SET
    preds = []
    targets = []

    class_names = ['air_conditioner', 'car_horn', 'children_playing', 'dog_bark', 'drilling', 'engine_idling', 'gun_shot', 'jackhammer', 'siren', 'street_music']

    for batch_idx, (data, target) in enumerate(loaders_transfer['valid']):
        data, target = data.cuda(), target.cuda()
        output = model_transfer(data)
        prediction = torch.argmax(output, dim=1)
        preds.append(prediction.cpu().numpy())
        targets.append(target.cpu().numpy())

    targets = np.concatenate(targets)
    preds = np.concatenate(preds)

    metrics_report_dict = classification_report(targets, preds, target_names=class_names, output_dict=True)
    fold_acc_dict = {'Test Fold' : fold_k , 'Accuracy' : metrics_report_dict['accuracy']}
    del metrics_report_dict['accuracy']

    if fold_k == 1:
        metrics_report = pd.DataFrame(metrics_report_dict).rename_axis('metric').reset_index()
        fold_accuracies = pd.DataFrame(fold_acc_dict,index=[0])
        metrics_report.insert(0,'Test Fold',fold_k)
        metrics_report.insert(0,'Data Representation', data_type)
        metrics_report.insert(0,'Model', model_name)
    else:
        metrics_report_temp = pd.DataFrame(metrics_report_dict).rename_axis('metric').reset_index()
        fold_accuracies_temp = pd.DataFrame(fold_acc_dict,index=[0])
        metrics_report_temp.insert(0,'Test Fold',fold_k)
        metrics_report_temp.insert(0,'Data Representation', data_type)
        metrics_report_temp.insert(0,'Model', model_name)
        metrics_report = pd.concat([metrics_report, metrics_report_temp])
        fold_accuracies = pd.concat([fold_accuracies, fold_accuracies_temp])
    
    del data, target, output, prediction, targets, preds

train_report.to_csv('results/TrainReportbyEpoch_' + model_name + '_' + data_type + '.csv', index=False)
metrics_report.to_csv('results/TestMetricsbyClass_' + model_name + '_' + data_type + '.csv', index=False)
fold_accuracies.to_csv('results/FoldAccuracies_' + model_name + '_' + data_type + '.csv', index=False)
# Out:
# Epoch: 1
# Training Loss: 0.000454
# Validation Loss: 0.002211
# Validation Accuracy: 0.325688
# Correct: 284.0 / 872.0
# Current LR: 0.001
# Epoch: 2
# Training Loss: 0.000219
# Validation Loss: 0.001958
# Validation Accuracy: 0.379587
# Correct: 331.0 / 872.0
# Current LR: 0.001
# Epoch: 3
# Training Loss: 0.000196
# Validation Loss: 0.002384
# Validation Accuracy: 0.348624
# Correct: 304.0 / 872.0
# Current LR: 0.001
# Epoch: 4
# Training Loss: 0.000177
# Validation Loss: 0.001853
# Validation Accuracy: 0.441514
# Correct: 385.0 / 872.0
# Current LR: 0.001
# Epoch: 5
# Training Loss: 0.000183
# Validation Loss: 0.001979
# Validation Accuracy: 0.434633
# Correct: 379.0 / 872.0
# Current LR: 0.001
# Epoch: 6
# Training Loss: 0.000177
# Validation Loss: 0.001879
# Validation Accuracy: 0.541284
# Correct: 472.0 / 872.0
# Current LR: 0.0007
# Epoch: 7
# Training Loss: 0.000141
# Validation Loss: 0.001790
# Validation Accuracy: 0.494266
# Correct: 431.0 / 872.0
# Current LR: 0.0007
# Epoch: 8
# Training Loss: 0.000126
# Validation Loss: 0.001594
# Validation Accuracy: 0.602064
# Correct: 525.0 / 872.0
# Current LR: 0.0007
# Epoch: 9
# Training Loss: 0.000111
# Validation Loss: 0.001487
# Validation Accuracy: 0.628440
# Correct: 548.0 / 872.0
# Current LR: 0.0007
# Epoch: 10
# Training Loss: 0.000102
# Validation Loss: 0.001544
# Validation Accuracy: 0.625000
# Correct: 545.0 / 872.0
# Current LR: 0.0007
# Epoch: 11
# Training Loss: 0.000081
# Validation Loss: 0.001434
# Validation Accuracy: 0.657110
# Correct: 573.0 / 872.0
# Current LR: 0.00049
# Epoch: 12
# Training Loss: 0.000074
# Validation Loss: 0.001332
# Validation Accuracy: 0.680046
# Correct: 593.0 / 872.0
# Current LR: 0.00049
# Epoch: 13
# Training Loss: 0.000065
# Validation Loss: 0.001362
# Validation Accuracy: 0.639908
# Correct: 558.0 / 872.0
# Current LR: 0.00049
# Epoch: 14
# Training Loss: 0.000059
# Validation Loss: 0.001466
# Validation Accuracy: 0.660550
# Correct: 576.0 / 872.0
# Current LR: 0.00049
# Epoch: 15
# Training Loss: 0.000058
# Validation Loss: 0.001712
# Validation Accuracy: 0.649083
# Correct: 566.0 / 872.0
# Current LR: 0.00049
# Epoch: 16
# Training Loss: 0.000046
# Validation Loss: 0.001819
# Validation Accuracy: 0.659404
# Correct: 575.0 / 872.0
# Current LR: 0.000343
# Epoch: 17
# Training Loss: 0.000039
# Validation Loss: 0.002050
# Validation Accuracy: 0.667431
# Correct: 582.0 / 872.0
# Current LR: 0.000343
# Epoch: 18
# Training Loss: 0.000033
# Validation Loss: 0.002124
# Validation Accuracy: 0.683486
# Correct: 596.0 / 872.0
# Current LR: 0.000343
# Epoch: 19
# Training Loss: 0.000034
# Validation Loss: 0.001871
# Validation Accuracy: 0.699541
# Correct: 610.0 / 872.0
# Current LR: 0.000343
# Epoch: 20
# Training Loss: 0.000030
# Validation Loss: 0.002012
# Validation Accuracy: 0.719037
# Correct: 627.0 / 872.0
# Current LR: 0.000343
# Epoch: 1
# Training Loss: 0.000418
# Validation Loss: 0.001981
# Validation Accuracy: 0.352477
# Correct: 313.0 / 888.0
# Current LR: 0.001
# Epoch: 2
# Training Loss: 0.000239
# Validation Loss: 0.001889
# Validation Accuracy: 0.430180
# Correct: 382.0 / 888.0
# Current LR: 0.001
# Epoch: 3
# Training Loss: 0.000205
# Validation Loss: 0.001797
# Validation Accuracy: 0.457207
# Correct: 406.0 / 888.0
# Current LR: 0.001
# Epoch: 4
# Training Loss: 0.000189
# Validation Loss: 0.001704
# Validation Accuracy: 0.470721
# Correct: 418.0 / 888.0
# Current LR: 0.001
# Epoch: 5
# Training Loss: 0.000186
# Validation Loss: 0.001647
# Validation Accuracy: 0.505631
# Correct: 449.0 / 888.0
# Current LR: 0.001
# Epoch: 6
# Training Loss: 0.000160
# Validation Loss: 0.001558
# Validation Accuracy: 0.543919
# Correct: 483.0 / 888.0
# Current LR: 0.0007
# Epoch: 7
# Training Loss: 0.000144
# Validation Loss: 0.001335
# Validation Accuracy: 0.629505
# Correct: 559.0 / 888.0
# Current LR: 0.0007
# Epoch: 8
# Training Loss: 0.000130
# Validation Loss: 0.001605
# Validation Accuracy: 0.578829
# Correct: 514.0 / 888.0
# Current LR: 0.0007
# Epoch: 9
# Training Loss: 0.000122
# Validation Loss: 0.001345
# Validation Accuracy: 0.599099
# Correct: 532.0 / 888.0
# Current LR: 0.0007
# Epoch: 10
# Training Loss: 0.000107
# Validation Loss: 0.001295
# Validation Accuracy: 0.643018
# Correct: 571.0 / 888.0
# Current LR: 0.0007
# Epoch: 11
# Training Loss: 0.000085
# Validation Loss: 0.001422
# Validation Accuracy: 0.653153
# Correct: 580.0 / 888.0
# Current LR: 0.00049
# Epoch: 12
# Training Loss: 0.000076
# Validation Loss: 0.001535
# Validation Accuracy: 0.653153
# Correct: 580.0 / 888.0
# Current LR: 0.00049
# Epoch: 13
# Training Loss: 0.000069
# Validation Loss: 0.001282
# Validation Accuracy: 0.699324
# Correct: 621.0 / 888.0
# Current LR: 0.00049
# Epoch: 14
# Training Loss: 0.000062
# Validation Loss: 0.001765
# Validation Accuracy: 0.680180
# Correct: 604.0 / 888.0
# Current LR: 0.00049
# Epoch: 15
# Training Loss: 0.000058
# Validation Loss: 0.001624
# Validation Accuracy: 0.673423
# Correct: 598.0 / 888.0
# Current LR: 0.00049
# Epoch: 16
# Training Loss: 0.000043
# Validation Loss: 0.001982
# Validation Accuracy: 0.664414
# Correct: 590.0 / 888.0
# Current LR: 0.000343
# Epoch: 17
# Training Loss: 0.000039
# Validation Loss: 0.001467
# Validation Accuracy: 0.679054
# Correct: 603.0 / 888.0
# Current LR: 0.000343
# Epoch: 18
# Training Loss: 0.000037
# Validation Loss: 0.001446
# Validation Accuracy: 0.665541
# Correct: 591.0 / 888.0
# Current LR: 0.000343
# Epoch: 19
# Training Loss: 0.000035
# Validation Loss: 0.002062
# Validation Accuracy: 0.658784
# Correct: 585.0 / 888.0
# Current LR: 0.000343
# Epoch: 20
# Training Loss: 0.000034
# Validation Loss: 0.001663
# Validation Accuracy: 0.704955
# Correct: 626.0 / 888.0
# Current LR: 0.000343
# Epoch: 1
# Training Loss: 0.000470
# Validation Loss: 0.002023
# Validation Accuracy: 0.252973
# Correct: 234.0 / 925.0
# Current LR: 0.001
# Epoch: 2
# Training Loss: 0.000222
# Validation Loss: 0.001751
# Validation Accuracy: 0.414054
# Correct: 383.0 / 925.0
# Current LR: 0.001
# Epoch: 3
# Training Loss: 0.000183
# Validation Loss: 0.001557
# Validation Accuracy: 0.490811
# Correct: 454.0 / 925.0
# Current LR: 0.001
# Epoch: 4
# Training Loss: 0.000161
# Validation Loss: 0.001522
# Validation Accuracy: 0.482162
# Correct: 446.0 / 925.0
# Current LR: 0.001
# Epoch: 5
# Training Loss: 0.000136
# Validation Loss: 0.001383
# Validation Accuracy: 0.572973
# Correct: 530.0 / 925.0
# Current LR: 0.001
# Epoch: 6
# Training Loss: 0.000108
# Validation Loss: 0.001524
# Validation Accuracy: 0.530811
# Correct: 491.0 / 925.0
# Current LR: 0.0007
# Epoch: 7
# Training Loss: 0.000098
# Validation Loss: 0.001775
# Validation Accuracy: 0.550270
# Correct: 509.0 / 925.0
# Current LR: 0.0007
# Epoch: 8
# Training Loss: 0.000092
# Validation Loss: 0.001550
# Validation Accuracy: 0.589189
# Correct: 545.0 / 925.0
# Current LR: 0.0007
# Epoch: 9
# Training Loss: 0.000084
# Validation Loss: 0.001454
# Validation Accuracy: 0.605405
# Correct: 560.0 / 925.0
# Current LR: 0.0007
# Epoch: 10
# Training Loss: 0.000077
# Validation Loss: 0.002157
# Validation Accuracy: 0.512432
# Correct: 474.0 / 925.0
# Current LR: 0.0007
# Epoch: 11
# Training Loss: 0.000057
# Validation Loss: 0.001498
# Validation Accuracy: 0.619459
# Correct: 573.0 / 925.0
# Current LR: 0.00049
# Epoch: 12
# Training Loss: 0.000050
# Validation Loss: 0.001765
# Validation Accuracy: 0.595676
# Correct: 551.0 / 925.0
# Current LR: 0.00049
# Epoch: 13
# Training Loss: 0.000045
# Validation Loss: 0.002028
# Validation Accuracy: 0.565405
# Correct: 523.0 / 925.0
# Current LR: 0.00049
# Epoch: 14
# Training Loss: 0.000050
# Validation Loss: 0.001715
# Validation Accuracy: 0.593514
# Correct: 549.0 / 925.0
# Current LR: 0.00049
# Epoch: 15
# Training Loss: 0.000046
# Validation Loss: 0.002167
# Validation Accuracy: 0.570811
# Correct: 528.0 / 925.0
# Current LR: 0.00049
# Epoch: 16
# Training Loss: 0.000036
# Validation Loss: 0.001752
# Validation Accuracy: 0.607568
# Correct: 562.0 / 925.0
# Current LR: 0.000343
# Epoch: 17
# Training Loss: 0.000028
# Validation Loss: 0.001790
# Validation Accuracy: 0.615135
# Correct: 569.0 / 925.0
# Current LR: 0.000343
# Epoch: 18
# Training Loss: 0.000028
# Validation Loss: 0.001793
# Validation Accuracy: 0.641081
# Correct: 593.0 / 925.0
# Current LR: 0.000343
# Epoch: 19
# Training Loss: 0.000026
# Validation Loss: 0.001655
# Validation Accuracy: 0.619459
# Correct: 573.0 / 925.0
# Current LR: 0.000343
# Epoch: 20
# Training Loss: 0.000024
# Validation Loss: 0.001811
# Validation Accuracy: 0.651892
# Correct: 603.0 / 925.0
# Current LR: 0.000343
# Epoch: 1
# Training Loss: 0.000492
# Validation Loss: 0.002001
# Validation Accuracy: 0.275758
# Correct: 273.0 / 990.0
# Current LR: 0.001
# Epoch: 2
# Training Loss: 0.000226
# Validation Loss: 0.001880
# Validation Accuracy: 0.296970
# Correct: 294.0 / 990.0
# Current LR: 0.001
# Epoch: 3
# Training Loss: 0.000196
# Validation Loss: 0.001607
# Validation Accuracy: 0.448485
# Correct: 444.0 / 990.0
# Current LR: 0.001
# Epoch: 4
# Training Loss: 0.000178
# Validation Loss: 0.001760
# Validation Accuracy: 0.364646
# Correct: 361.0 / 990.0
# Current LR: 0.001
# Epoch: 5
# Training Loss: 0.000161
# Validation Loss: 0.001538
# Validation Accuracy: 0.490909
# Correct: 486.0 / 990.0
# Current LR: 0.001
# Epoch: 6
# Training Loss: 0.000128
# Validation Loss: 0.001143
# Validation Accuracy: 0.615152
# Correct: 609.0 / 990.0
# Current LR: 0.0007
# Epoch: 7
# Training Loss: 0.000113
# Validation Loss: 0.001335
# Validation Accuracy: 0.586869
# Correct: 581.0 / 990.0
# Current LR: 0.0007
# Epoch: 8
# Training Loss: 0.000103
# Validation Loss: 0.001106
# Validation Accuracy: 0.667677
# Correct: 661.0 / 990.0
# Current LR: 0.0007
# Epoch: 9
# Training Loss: 0.000092
# Validation Loss: 0.000928
# Validation Accuracy: 0.694949
# Correct: 688.0 / 990.0
# Current LR: 0.0007
# Epoch: 10
# Training Loss: 0.000086
# Validation Loss: 0.001393
# Validation Accuracy: 0.622222
# Correct: 616.0 / 990.0
# Current LR: 0.0007
# Epoch: 11
# Training Loss: 0.000065
# Validation Loss: 0.001236
# Validation Accuracy: 0.667677
# Correct: 661.0 / 990.0
# Current LR: 0.00049
# Epoch: 12
# Training Loss: 0.000061
# Validation Loss: 0.001271
# Validation Accuracy: 0.692929
# Correct: 686.0 / 990.0
# Current LR: 0.00049
# Epoch: 13
# Training Loss: 0.000054
# Validation Loss: 0.001094
# Validation Accuracy: 0.740404
# Correct: 733.0 / 990.0
# Current LR: 0.00049
# Epoch: 14
# Training Loss: 0.000051
# Validation Loss: 0.000984
# Validation Accuracy: 0.751515
# Correct: 744.0 / 990.0
# Current LR: 0.00049
# Epoch: 15
# Training Loss: 0.000050
# Validation Loss: 0.001366
# Validation Accuracy: 0.686869
# Correct: 680.0 / 990.0
# Current LR: 0.00049
# Epoch: 16
# Training Loss: 0.000038
# Validation Loss: 0.001160
# Validation Accuracy: 0.723232
# Correct: 716.0 / 990.0
# Current LR: 0.000343
# Epoch: 17
# Training Loss: 0.000033
# Validation Loss: 0.001012
# Validation Accuracy: 0.756566
# Correct: 749.0 / 990.0
# Current LR: 0.000343
# Epoch: 18
# Training Loss: 0.000030
# Validation Loss: 0.001040
# Validation Accuracy: 0.745455
# Correct: 738.0 / 990.0
# Current LR: 0.000343
# Epoch: 19
# Training Loss: 0.000030
# Validation Loss: 0.001316
# Validation Accuracy: 0.728283
# Correct: 721.0 / 990.0
# Current LR: 0.000343
# Epoch: 20
# Training Loss: 0.000028
# Validation Loss: 0.001215
# Validation Accuracy: 0.744444
# Correct: 737.0 / 990.0
# Current LR: 0.000343
# Epoch: 1
# Training Loss: 0.000441
# Validation Loss: 0.002193
# Validation Accuracy: 0.213904
# Correct: 200.0 / 935.0
# Current LR: 0.001
# Epoch: 2
# Training Loss: 0.000263
# Validation Loss: 0.002117
# Validation Accuracy: 0.311230
# Correct: 291.0 / 935.0
# Current LR: 0.001
# Epoch: 3
# Training Loss: 0.000248
# Validation Loss: 0.002122
# Validation Accuracy: 0.278075
# Correct: 260.0 / 935.0
# Current LR: 0.001
# Epoch: 4
# Training Loss: 0.000300
# Validation Loss: 0.002465
# Validation Accuracy: 0.128342
# Correct: 120.0 / 935.0
# Current LR: 0.001
# Epoch: 5
# Training Loss: 0.000291
# Validation Loss: 0.002500
# Validation Accuracy: 0.128342
# Correct: 120.0 / 935.0
# Current LR: 0.001
# Epoch: 6
# Training Loss: 0.000291
# Validation Loss: 0.002480
# Validation Accuracy: 0.105882
# Correct: 99.0 / 935.0
# Current LR: 0.0007
# Epoch: 7
# Training Loss: 0.000290
# Validation Loss: 0.002478
# Validation Accuracy: 0.105882
# Correct: 99.0 / 935.0
# Current LR: 0.0007
# Epoch: 8
# Training Loss: 0.000290
# Validation Loss: 0.002489
# Validation Accuracy: 0.105882
# Correct: 99.0 / 935.0
# Current LR: 0.0007
# Epoch: 9
# Training Loss: 0.000290
# Validation Loss: 0.002474
# Validation Accuracy: 0.106952
# Correct: 100.0 / 935.0
# Current LR: 0.0007
# Epoch: 10
# Training Loss: 0.000290
# Validation Loss: 0.002461
# Validation Accuracy: 0.128342
# Correct: 120.0 / 935.0
# Current LR: 0.0007
# Epoch: 11
# Training Loss: 0.000290
# Validation Loss: 0.002479
# Validation Accuracy: 0.105882
# Correct: 99.0 / 935.0
# Current LR: 0.00049
# Epoch: 12
# Training Loss: 0.000290
# Validation Loss: 0.002471
# Validation Accuracy: 0.106952
# Correct: 100.0 / 935.0
# Current LR: 0.00049
# Epoch: 13
# Training Loss: 0.000290
# Validation Loss: 0.002473
# Validation Accuracy: 0.106952
# Correct: 100.0 / 935.0
# Current LR: 0.00049
# Epoch: 14
# Training Loss: 0.000290
# Validation Loss: 0.002487
# Validation Accuracy: 0.106952
# Correct: 100.0 / 935.0
# Current LR: 0.00049
# Epoch: 15
# Training Loss: 0.000290
# Validation Loss: 0.002480
# Validation Accuracy: 0.106952
# Correct: 100.0 / 935.0
# Current LR: 0.00049
# Epoch: 16
# Training Loss: 0.000290
# Validation Loss: 0.002486
# Validation Accuracy: 0.106952
# Correct: 100.0 / 935.0
# Current LR: 0.000343
# Epoch: 17
# Training Loss: 0.000290
# Validation Loss: 0.002468
# Validation Accuracy: 0.114439
# Correct: 107.0 / 935.0
# Current LR: 0.000343
# Epoch: 18
# Training Loss: 0.000290
# Validation Loss: 0.002474
# Validation Accuracy: 0.106952
# Correct: 100.0 / 935.0
# Current LR: 0.000343
# Epoch: 19
# Training Loss: 0.000290
# Validation Loss: 0.002475
# Validation Accuracy: 0.106952
# Correct: 100.0 / 935.0
# Current LR: 0.000343
# Epoch: 20
# Training Loss: 0.000290
# Validation Loss: 0.002475
# Validation Accuracy: 0.106952
# Correct: 100.0 / 935.0
# Current LR: 0.000343
# c:\Users\khamm\miniconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\khamm\miniconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\khamm\miniconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch: 1
# Training Loss: 0.000388
# Validation Loss: 0.002304
# Validation Accuracy: 0.280680
# Correct: 231.0 / 823.0
# Current LR: 0.001
# Epoch: 2
# Training Loss: 0.000214
# Validation Loss: 0.002349
# Validation Accuracy: 0.371810
# Correct: 306.0 / 823.0
# Current LR: 0.001
# Epoch: 3
# Training Loss: 0.000183
# Validation Loss: 0.001814
# Validation Accuracy: 0.452005
# Correct: 372.0 / 823.0
# Current LR: 0.001
# Epoch: 4
# Training Loss: 0.000160
# Validation Loss: 0.001758
# Validation Accuracy: 0.460510
# Correct: 379.0 / 823.0
# Current LR: 0.001
# Epoch: 5
# Training Loss: 0.000153
# Validation Loss: 0.001794
# Validation Accuracy: 0.459295
# Correct: 378.0 / 823.0
# Current LR: 0.001
# Epoch: 6
# Training Loss: 0.000118
# Validation Loss: 0.001620
# Validation Accuracy: 0.551640
# Correct: 454.0 / 823.0
# Current LR: 0.0007
# Epoch: 7
# Training Loss: 0.000103
# Validation Loss: 0.001728
# Validation Accuracy: 0.513973
# Correct: 423.0 / 823.0
# Current LR: 0.0007
# Epoch: 8
# Training Loss: 0.000097
# Validation Loss: 0.001864
# Validation Accuracy: 0.596598
# Correct: 491.0 / 823.0
# Current LR: 0.0007
# Epoch: 9
# Training Loss: 0.000084
# Validation Loss: 0.001583
# Validation Accuracy: 0.631835
# Correct: 520.0 / 823.0
# Current LR: 0.0007
# Epoch: 10
# Training Loss: 0.000072
# Validation Loss: 0.001469
# Validation Accuracy: 0.647631
# Correct: 533.0 / 823.0
# Current LR: 0.0007
# Epoch: 11
# Training Loss: 0.000060
# Validation Loss: 0.001518
# Validation Accuracy: 0.673147
# Correct: 554.0 / 823.0
# Current LR: 0.00049
# Epoch: 12
# Training Loss: 0.000050
# Validation Loss: 0.001604
# Validation Accuracy: 0.674362
# Correct: 555.0 / 823.0
# Current LR: 0.00049
# Epoch: 13
# Training Loss: 0.000050
# Validation Loss: 0.001478
# Validation Accuracy: 0.686513
# Correct: 565.0 / 823.0
# Current LR: 0.00049
# Epoch: 14
# Training Loss: 0.000044
# Validation Loss: 0.001503
# Validation Accuracy: 0.682868
# Correct: 562.0 / 823.0
# Current LR: 0.00049
# Epoch: 15
# Training Loss: 0.000047
# Validation Loss: 0.001569
# Validation Accuracy: 0.669502
# Correct: 551.0 / 823.0
# Current LR: 0.00049
# Epoch: 16
# Training Loss: 0.000032
# Validation Loss: 0.001574
# Validation Accuracy: 0.685298
# Correct: 564.0 / 823.0
# Current LR: 0.000343
# Epoch: 17
# Training Loss: 0.000027
# Validation Loss: 0.001587
# Validation Accuracy: 0.703524
# Correct: 579.0 / 823.0
# Current LR: 0.000343
# Epoch: 18
# Training Loss: 0.000028
# Validation Loss: 0.001538
# Validation Accuracy: 0.681652
# Correct: 561.0 / 823.0
# Current LR: 0.000343
# Epoch: 19
# Training Loss: 0.000024
# Validation Loss: 0.001518
# Validation Accuracy: 0.712029
# Correct: 586.0 / 823.0
# Current LR: 0.000343
# Epoch: 20
# Training Loss: 0.000025
# Validation Loss: 0.001476
# Validation Accuracy: 0.714459
# Correct: 588.0 / 823.0
# Current LR: 0.000343
# Epoch: 1
# Training Loss: 0.000426
# Validation Loss: 0.002511
# Validation Accuracy: 0.208831
# Correct: 175.0 / 838.0
# Current LR: 0.001
# Epoch: 2
# Training Loss: 0.000259
# Validation Loss: 0.002324
# Validation Accuracy: 0.250597
# Correct: 210.0 / 838.0
# Current LR: 0.001
# Epoch: 3
# Training Loss: 0.000237
# Validation Loss: 0.002136
# Validation Accuracy: 0.329356
# Correct: 276.0 / 838.0
# Current LR: 0.001
# Epoch: 4
# Training Loss: 0.000247
# Validation Loss: 0.002694
# Validation Accuracy: 0.189737
# Correct: 159.0 / 838.0
# Current LR: 0.001
# Epoch: 5
# Training Loss: 0.000229
# Validation Loss: 0.002483
# Validation Accuracy: 0.326969
# Correct: 274.0 / 838.0
# Current LR: 0.001
# Epoch: 6
# Training Loss: 0.000187
# Validation Loss: 0.001741
# Validation Accuracy: 0.504773
# Correct: 423.0 / 838.0
# Current LR: 0.0007
# Epoch: 7
# Training Loss: 0.000160
# Validation Loss: 0.001456
# Validation Accuracy: 0.595465
# Correct: 499.0 / 838.0
# Current LR: 0.0007
# Epoch: 8
# Training Loss: 0.000138
# Validation Loss: 0.001415
# Validation Accuracy: 0.609785
# Correct: 511.0 / 838.0
# Current LR: 0.0007
# Epoch: 9
# Training Loss: 0.000116
# Validation Loss: 0.001264
# Validation Accuracy: 0.634845
# Correct: 532.0 / 838.0
# Current LR: 0.0007
# Epoch: 10
# Training Loss: 0.000100
# Validation Loss: 0.001219
# Validation Accuracy: 0.682578
# Correct: 572.0 / 838.0
# Current LR: 0.0007
# Epoch: 11
# Training Loss: 0.000084
# Validation Loss: 0.001136
# Validation Accuracy: 0.670644
# Correct: 562.0 / 838.0
# Current LR: 0.00049
# Epoch: 12
# Training Loss: 0.000070
# Validation Loss: 0.001176
# Validation Accuracy: 0.708831
# Correct: 594.0 / 838.0
# Current LR: 0.00049
# Epoch: 13
# Training Loss: 0.000062
# Validation Loss: 0.001262
# Validation Accuracy: 0.662291
# Correct: 555.0 / 838.0
# Current LR: 0.00049
# Epoch: 14
# Training Loss: 0.000053
# Validation Loss: 0.002082
# Validation Accuracy: 0.699284
# Correct: 586.0 / 838.0
# Current LR: 0.00049
# Epoch: 15
# Training Loss: 0.000051
# Validation Loss: 0.001388
# Validation Accuracy: 0.663484
# Correct: 556.0 / 838.0
# Current LR: 0.00049
# Epoch: 16
# Training Loss: 0.000040
# Validation Loss: 0.001130
# Validation Accuracy: 0.739857
# Correct: 620.0 / 838.0
# Current LR: 0.000343
# Epoch: 17
# Training Loss: 0.000033
# Validation Loss: 0.001160
# Validation Accuracy: 0.739857
# Correct: 620.0 / 838.0
# Current LR: 0.000343
# Epoch: 18
# Training Loss: 0.000033
# Validation Loss: 0.001453
# Validation Accuracy: 0.743437
# Correct: 623.0 / 838.0
# Current LR: 0.000343
# Epoch: 19
# Training Loss: 0.000034
# Validation Loss: 0.001243
# Validation Accuracy: 0.749403
# Correct: 628.0 / 838.0
# Current LR: 0.000343
# Epoch: 20
# Training Loss: 0.000029
# Validation Loss: 0.001632
# Validation Accuracy: 0.706444
# Correct: 592.0 / 838.0
# Current LR: 0.000343
# Epoch: 1
# Training Loss: 0.000454
# Validation Loss: 0.002874
# Validation Accuracy: 0.116395
# Correct: 93.0 / 799.0
# Current LR: 0.001
# Epoch: 2
# Training Loss: 0.000288
# Validation Loss: 0.002830
# Validation Accuracy: 0.116395
# Correct: 93.0 / 799.0
# Current LR: 0.001
# Epoch: 3
# Training Loss: 0.000287
# Validation Loss: 0.002820
# Validation Accuracy: 0.116395
# Correct: 93.0 / 799.0
# Current LR: 0.001
# Epoch: 4
# Training Loss: 0.000287
# Validation Loss: 0.002818
# Validation Accuracy: 0.110138
# Correct: 88.0 / 799.0
# Current LR: 0.001
# Epoch: 5
# Training Loss: 0.000287
# Validation Loss: 0.002813
# Validation Accuracy: 0.125156
# Correct: 100.0 / 799.0
# Current LR: 0.001
# Epoch: 6
# Training Loss: 0.000286
# Validation Loss: 0.002809
# Validation Accuracy: 0.125156
# Correct: 100.0 / 799.0
# Current LR: 0.0007
# Epoch: 7
# Training Loss: 0.000286
# Validation Loss: 0.002812
# Validation Accuracy: 0.116395
# Correct: 93.0 / 799.0
# Current LR: 0.0007
# Epoch: 8
# Training Loss: 0.000286
# Validation Loss: 0.002812
# Validation Accuracy: 0.116395
# Correct: 93.0 / 799.0
# Current LR: 0.0007
# Epoch: 9
# Training Loss: 0.000286
# Validation Loss: 0.002816
# Validation Accuracy: 0.125156
# Correct: 100.0 / 799.0
# Current LR: 0.0007
# Epoch: 10
# Training Loss: 0.000286
# Validation Loss: 0.002819
# Validation Accuracy: 0.125156
# Correct: 100.0 / 799.0
# Current LR: 0.0007
# Epoch: 11
# Training Loss: 0.000286
# Validation Loss: 0.002813
# Validation Accuracy: 0.097622
# Correct: 78.0 / 799.0
# Current LR: 0.00049
# Epoch: 12
# Training Loss: 0.000286
# Validation Loss: 0.002816
# Validation Accuracy: 0.116395
# Correct: 93.0 / 799.0
# Current LR: 0.00049
# Epoch: 13
# Training Loss: 0.000286
# Validation Loss: 0.002810
# Validation Accuracy: 0.125156
# Correct: 100.0 / 799.0
# Current LR: 0.00049
# Epoch: 14
# Training Loss: 0.000286
# Validation Loss: 0.002810
# Validation Accuracy: 0.125156
# Correct: 100.0 / 799.0
# Current LR: 0.00049
# Epoch: 15
# Training Loss: 0.000286
# Validation Loss: 0.002807
# Validation Accuracy: 0.125156
# Correct: 100.0 / 799.0
# Current LR: 0.00049
# Epoch: 16
# Training Loss: 0.000286
# Validation Loss: 0.002805
# Validation Accuracy: 0.125156
# Correct: 100.0 / 799.0
# Current LR: 0.000343
# Epoch: 17
# Training Loss: 0.000286
# Validation Loss: 0.002810
# Validation Accuracy: 0.116395
# Correct: 93.0 / 799.0
# Current LR: 0.000343
# Epoch: 18
# Training Loss: 0.000286
# Validation Loss: 0.002810
# Validation Accuracy: 0.125156
# Correct: 100.0 / 799.0
# Current LR: 0.000343
# Epoch: 19
# Training Loss: 0.000286
# Validation Loss: 0.002814
# Validation Accuracy: 0.125156
# Correct: 100.0 / 799.0
# Current LR: 0.000343
# Epoch: 20
# Training Loss: 0.000286
# Validation Loss: 0.002810
# Validation Accuracy: 0.125156
# Correct: 100.0 / 799.0
# Current LR: 0.000343
# c:\Users\khamm\miniconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\khamm\miniconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\khamm\miniconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch: 1
# Training Loss: 0.000405
# Validation Loss: 0.001865
# Validation Accuracy: 0.397059
# Correct: 324.0 / 816.0
# Current LR: 0.001
# Epoch: 2
# Training Loss: 0.000204
# Validation Loss: 0.001820
# Validation Accuracy: 0.491422
# Correct: 401.0 / 816.0
# Current LR: 0.001
# Epoch: 3
# Training Loss: 0.000179
# Validation Loss: 0.001804
# Validation Accuracy: 0.482843
# Correct: 394.0 / 816.0
# Current LR: 0.001
# Epoch: 4
# Training Loss: 0.000159
# Validation Loss: 0.001620
# Validation Accuracy: 0.557598
# Correct: 455.0 / 816.0
# Current LR: 0.001
# Epoch: 5
# Training Loss: 0.000138
# Validation Loss: 0.002079
# Validation Accuracy: 0.574755
# Correct: 469.0 / 816.0
# Current LR: 0.001
# Epoch: 6
# Training Loss: 0.000110
# Validation Loss: 0.002091
# Validation Accuracy: 0.623775
# Correct: 509.0 / 816.0
# Current LR: 0.0007
# Epoch: 7
# Training Loss: 0.000098
# Validation Loss: 0.001398
# Validation Accuracy: 0.649510
# Correct: 530.0 / 816.0
# Current LR: 0.0007
# Epoch: 8
# Training Loss: 0.000090
# Validation Loss: 0.001871
# Validation Accuracy: 0.609069
# Correct: 497.0 / 816.0
# Current LR: 0.0007
# Epoch: 9
# Training Loss: 0.000083
# Validation Loss: 0.001505
# Validation Accuracy: 0.681373
# Correct: 556.0 / 816.0
# Current LR: 0.0007
# Epoch: 10
# Training Loss: 0.000082
# Validation Loss: 0.001540
# Validation Accuracy: 0.675245
# Correct: 551.0 / 816.0
# Current LR: 0.0007
# Epoch: 11
# Training Loss: 0.000058
# Validation Loss: 0.001972
# Validation Accuracy: 0.664216
# Correct: 542.0 / 816.0
# Current LR: 0.00049
# Epoch: 12
# Training Loss: 0.000050
# Validation Loss: 0.001959
# Validation Accuracy: 0.667892
# Correct: 545.0 / 816.0
# Current LR: 0.00049
# Epoch: 13
# Training Loss: 0.000049
# Validation Loss: 0.002422
# Validation Accuracy: 0.686275
# Correct: 560.0 / 816.0
# Current LR: 0.00049
# Epoch: 14
# Training Loss: 0.000045
# Validation Loss: 0.001800
# Validation Accuracy: 0.709559
# Correct: 579.0 / 816.0
# Current LR: 0.00049
# Epoch: 15
# Training Loss: 0.000047
# Validation Loss: 0.001883
# Validation Accuracy: 0.671569
# Correct: 548.0 / 816.0
# Current LR: 0.00049
# Epoch: 16
# Training Loss: 0.000032
# Validation Loss: 0.002027
# Validation Accuracy: 0.702206
# Correct: 573.0 / 816.0
# Current LR: 0.000343
# Epoch: 17
# Training Loss: 0.000028
# Validation Loss: 0.002142
# Validation Accuracy: 0.691176
# Correct: 564.0 / 816.0
# Current LR: 0.000343
# Epoch: 18
# Training Loss: 0.000028
# Validation Loss: 0.002370
# Validation Accuracy: 0.693627
# Correct: 566.0 / 816.0
# Current LR: 0.000343
# Epoch: 19
# Training Loss: 0.000024
# Validation Loss: 0.002701
# Validation Accuracy: 0.689951
# Correct: 563.0 / 816.0
# Current LR: 0.000343
# Epoch: 20
# Training Loss: 0.000025
# Validation Loss: 0.002427
# Validation Accuracy: 0.696078
# Correct: 568.0 / 816.0
# Current LR: 0.000343
# Epoch: 1
# Training Loss: 0.000480
# Validation Loss: 0.001917
# Validation Accuracy: 0.416965
# Correct: 349.0 / 837.0
# Current LR: 0.001
# Epoch: 2
# Training Loss: 0.000211
# Validation Loss: 0.002090
# Validation Accuracy: 0.301075
# Correct: 252.0 / 837.0
# Current LR: 0.001
# Epoch: 3
# Training Loss: 0.000220
# Validation Loss: 0.001795
# Validation Accuracy: 0.446834
# Correct: 374.0 / 837.0
# Current LR: 0.001
# Epoch: 4
# Training Loss: 0.000194
# Validation Loss: 0.001629
# Validation Accuracy: 0.508961
# Correct: 426.0 / 837.0
# Current LR: 0.001
# Epoch: 5
# Training Loss: 0.000178
# Validation Loss: 0.001483
# Validation Accuracy: 0.572282
# Correct: 479.0 / 837.0
# Current LR: 0.001
# Epoch: 6
# Training Loss: 0.000148
# Validation Loss: 0.001491
# Validation Accuracy: 0.525687
# Correct: 440.0 / 837.0
# Current LR: 0.0007
# Epoch: 7
# Training Loss: 0.000140
# Validation Loss: 0.001472
# Validation Accuracy: 0.573477
# Correct: 480.0 / 837.0
# Current LR: 0.0007
# Epoch: 8
# Training Loss: 0.000122
# Validation Loss: 0.001182
# Validation Accuracy: 0.676225
# Correct: 566.0 / 837.0
# Current LR: 0.0007
# Epoch: 9
# Training Loss: 0.000114
# Validation Loss: 0.001288
# Validation Accuracy: 0.626045
# Correct: 524.0 / 837.0
# Current LR: 0.0007
# Epoch: 10
# Training Loss: 0.000108
# Validation Loss: 0.001209
# Validation Accuracy: 0.666667
# Correct: 558.0 / 837.0
# Current LR: 0.0007
# Epoch: 11
# Training Loss: 0.000082
# Validation Loss: 0.001071
# Validation Accuracy: 0.710872
# Correct: 595.0 / 837.0
# Current LR: 0.00049
# Epoch: 12
# Training Loss: 0.000075
# Validation Loss: 0.001024
# Validation Accuracy: 0.734767
# Correct: 615.0 / 837.0
# Current LR: 0.00049
# Epoch: 13
# Training Loss: 0.000068
# Validation Loss: 0.001186
# Validation Accuracy: 0.681004
# Correct: 570.0 / 837.0
# Current LR: 0.00049
# Epoch: 14
# Training Loss: 0.000066
# Validation Loss: 0.001069
# Validation Accuracy: 0.732378
# Correct: 613.0 / 837.0
# Current LR: 0.00049
# Epoch: 15
# Training Loss: 0.000056
# Validation Loss: 0.001355
# Validation Accuracy: 0.651135
# Correct: 545.0 / 837.0
# Current LR: 0.00049
# Epoch: 16
# Training Loss: 0.000047
# Validation Loss: 0.001066
# Validation Accuracy: 0.747909
# Correct: 626.0 / 837.0
# Current LR: 0.000343
# Epoch: 17
# Training Loss: 0.000039
# Validation Loss: 0.001221
# Validation Accuracy: 0.752688
# Correct: 630.0 / 837.0
# Current LR: 0.000343
# Epoch: 18
# Training Loss: 0.000042
# Validation Loss: 0.001348
# Validation Accuracy: 0.692951
# Correct: 580.0 / 837.0
# Current LR: 0.000343
# Epoch: 19
# Training Loss: 0.000036
# Validation Loss: 0.001066
# Validation Accuracy: 0.753883
# Correct: 631.0 / 837.0
# Current LR: 0.000343
# Epoch: 20
# Training Loss: 0.000035
# Validation Loss: 0.001191
# Validation Accuracy: 0.756272
# Correct: 633.0 / 837.0
# Current LR: 0.000343
